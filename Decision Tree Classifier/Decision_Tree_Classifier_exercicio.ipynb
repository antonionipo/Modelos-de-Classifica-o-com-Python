# %% [markdown]
# <a href="https://colab.research.google.com/github/antonionipo/Modelos-de-Classifica-o-com-Python/blob/main/Decision%20Tree%20Classifier/Decision_Tree_Classifier_exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
sales = pd.read_excel('vendas.xlsx')
sales.head()
# Out:
#    media_rating  media_pedidos test cliente_comprou
# 0           1.5             11   No             Yes
# 1           2.5             11   No              No
# 2           2.5             11   No              No
# 3           1.5             13   No             Yes
# 4           2.5             13   No              No

# %%
X = pd.get_dummies(sales.drop('cliente_comprou', axis=1))
y = sales['cliente_comprou']

# %%
tree = tree.DecisionTreeClassifier()
model = tree.fit(X, y)

# %%
fig = plt.figure(figsize=(18,6))
plot_tree(model, feature_names=X.columns, filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'media_pedidos <= 21.0\ngini = 0.5\nsamples = 30\nvalue = [15, 15]'),
#  Text(0.25, 0.75, 'media_rating <= 2.0\ngini = 0.401\nsamples = 18\nvalue = [13, 5]'),
#  Text(0.375, 0.8333333333333333, 'True  '),
#  Text(0.125, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.375, 0.5833333333333334, 'media_rating <= 4.0\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.25, 0.4166666666666667, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.5, 0.4166666666666667, 'media_pedidos <= 12.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.375, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.625, 0.25, 'media_pedidos <= 14.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...
